# %% [markdown]
# # Lab 2 - Probability in Machine Learning
#
# Welcome to the Probability in Machine Learning Lab! In this lab, we will explore how probability theory plays a crucial role in machine learning. We will start with a simple coin flip example to grasp the basics and then move on to build a Bayesian email classifier. Let's dive in!
#
# ## Setting Up the Environment
#
# First, let's import the necessary libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Part 1: Coin Flip Probability Example
#
# ### Objective:
# To understand basic probability and Python coding through a coin flip example.
#
# ### Simulating Coin Flips
# We will simulate flipping a coin 1000 times.

# %%
# Simulating 1000 coin flips, 0 for 'tails' and 1 for 'heads'
coin_flips = np.random.choice(['heads', 'tails'], size=1000)
df_coin = pd.DataFrame({'flip_result': coin_flips})

# %% [markdown]
# ### Analyzing Flip Results
# Now, let's count how many heads and tails we got.

# %%
flip_counts = df_coin['flip_result'].value_counts()
print(flip_counts)
# Out:
# flip_result
# tails    507
# heads    493
# Name: count, dtype: int64

# %% [markdown]
# ### Calculating Probabilities
# Next, we will calculate the probability of getting heads or tails.

# %%
p_heads = flip_counts['heads'] / len(df_coin)
p_tails = flip_counts['tails'] / len(df_coin)
print(f"Probability of Heads: {p_heads}")
print(f"Probability of Tails: {p_tails}")
# Out:
# Probability of Heads: 0.493
# Probability of Tails: 0.507

# %% [markdown]
# ## Part 2: Bayesian Email Classifier
#
# ### Objective:
# Now, you will build a Bayesian email classifier to differentiate between 'spam' and 'ham' (not spam) emails.
#
# ### Task 1: Exploring the Dataset
# First, load and explore the dataset. You can either find and use a dataset or use the following code to simulate a sample dataset.

# %%
# The following code snippet creates a simulated email classification (spam and not spam) dataset with 1000 data points.

import pandas as pd
import numpy as np

# Sample size
n_samples = 1000

# Simulating data
np.random.seed(42)

data = {
    'email_length': np.random.normal(100, 20, n_samples).astype(int),
    'contains_free': np.random.choice([0, 1], size=n_samples, p=[0.7, 0.3]),
    'contains_winner': np.random.choice([0, 1], size=n_samples, p=[0.5, 0.5]),
    'time_of_day': np.random.choice(['morning', 'afternoon', 'evening', 'night'], n_samples),
    'label': np.random.choice(['spam', 'ham'], n_samples, p=[0.4, 0.6])
}

df = pd.DataFrame(data)

#Replace labels with ones with some relationship
for index, row in df.iterrows():
    prob = min(1, .7 *row["contains_free"] + .7*row["contains_winner"]+.1)
    df.at[index, 'label'] = np.random.choice(['spam', 'ham'], p=[prob, 1-prob])

# Saving the dataset
df.to_csv('simulated_email_dataset.csv', index=False)

# %%
# Load the dataset (Replace 'path_to_dataset' with the actual file path). You can uncomment the codes below. Notice what `df_emails.head()` is representing.
df_emails = pd.read_csv('simulated_email_dataset.csv')
df_emails.head()
# Out:
#    email_length  contains_free  contains_winner time_of_day label
# 0           109              0                0     morning   ham
# 1            97              0                0     morning   ham
# 2           112              0                0     morning   ham
# 3           130              1                0   afternoon  spam
# 4            95              0                1   afternoon  spam

# %% [markdown]
# ### Task 2: Data Preprocessing
# You need to preprocess the data for analysis. This involves normalizing and encoding the features.

# %%
# Your code for Data Preprocessing goes here
email_length_min = df_emails['email_length'].min()
email_length_max = df_emails['email_length'].max()
df_emails['email_length'] = (df_emails['email_length'] - email_length_min) / (email_length_max - email_length_min)
cutsOfEmailLength = ['small', 'medium', 'large']
df_emails['len_cuts'] = pd.qcut(df_emails['email_length'], len(cutsOfEmailLength), labels=cutsOfEmailLength)
df_emails.head()
# Out:
#    email_length  contains_free  contains_winner time_of_day label len_cuts
# 0      0.521127              0                0     morning   ham    large
# 1      0.436620              0                0     morning   ham   medium
# 2      0.542254              0                0     morning   ham    large
# 3      0.669014              1                0   afternoon  spam    large
# 4      0.422535              0                1   afternoon  spam   medium

# %% [markdown]
# ### Task 3: Probability Calculation
# Calculate the probability of spam and ham emails in the dataset.

# %%
# Your code for calculating the probability of spam and ham emails in the dataset goes here

total_emails = len(df_emails['label'])
total_ham_emails = df_emails['label'].value_counts()['ham']
total_spam_emails = df_emails['label'].value_counts()['spam']
prob_ham = total_ham_emails/total_emails
prob_spam = total_spam_emails/total_emails
print(f'probabilty ham emails {prob_ham}')
print(f'probabilty spam emails {prob_spam}')
# Out:
# probabilty ham emails 0.41
# probabilty spam emails 0.59

# %% [markdown]
# ### Task 4: Implementing Bayes' Theorem
# Implement Bayes' Theorem to classify emails as spam or ham.

# %%
# Function to calculate probabilities
def calculate_probabilities(feature, df: pd.DataFrame, label, value):
    if feature == 'label':  # Skip the label column
        return
    count_label = len(df[df['label'] == label])
    if count_label == 0:  # Avoid division by zero
        return 0
    return len(df[(df[feature] == value) & (df['label'] == label)]) / count_label


# Function to calculate conditional probabilities
def calc_conditional_probs(df, data, label, features):
    """Calculate all conditional probabilities for a given label (spam or ham) using a dictionary."""
    likelihoods = {}
    for feature in features:
        likelihoods[feature] = calculate_probabilities(feature, df, label, data[feature])
    return likelihoods


# Function to classify an email using Bayes' Theorem
def bayes_classify(data, df: pd.DataFrame):
    data['email_length'] = (data['email_length'] - email_length_min) / (email_length_max - email_length_min)

    # Calculate prior probabilities
    total_emails = len(df['label'])
    prob_spam = len(df[df['label'] == 'spam']) / total_emails
    prob_ham = len(df[df['label'] == 'ham']) / total_emails

    # Assign email_length category based on bins
    _, length_divisions = pd.qcut(df['email_length'], 3, retbins=True)
    print(f'length divisions {length_divisions}')

    
    # Assign the appropriate length category
    print(f'email length {data['email_length']}')
    for i in range(len(length_divisions) - 1):

        if length_divisions[i] <= data['email_length'] < length_divisions[i + 1] or (i == len(length_divisions) - 2 and data['email_length'] == length_divisions[i + 1]):
            data['len_cuts'] = cutsOfEmailLength[i]
            break


    # Calculate likelihoods for spam and ham
    likelihoods_spam = calc_conditional_probs(df, data, 'spam', ['len_cuts', 'contains_free', 'contains_winner', 'time_of_day'])
    likelihoods_ham = calc_conditional_probs(df, data, 'ham', ['len_cuts', 'contains_free', 'contains_winner', 'time_of_day'])

    # Extract probabilities
    P_Len_given_spam = likelihoods_spam['len_cuts']
    P_free_given_spam = likelihoods_spam['contains_free']
    P_winner_given_spam = likelihoods_spam['contains_winner']
    P_tod_given_spam = likelihoods_spam['time_of_day']

    P_Len_given_ham = likelihoods_ham['len_cuts']
    P_free_given_ham = likelihoods_ham['contains_free']
    P_winner_given_ham = likelihoods_ham['contains_winner']
    P_tod_given_ham = likelihoods_ham['time_of_day']

    # Calculate P(spam | data) using Bayes' Theorem
    numerator_spam = P_Len_given_spam * P_free_given_spam * P_winner_given_spam * P_tod_given_spam * prob_spam
    numerator_ham = P_Len_given_ham * P_free_given_ham * P_winner_given_ham * P_tod_given_ham * prob_ham

    P_spam_given_data = numerator_spam / (numerator_spam + numerator_ham)

    # Return the probability of the email being spam
    return P_spam_given_data

# %% [markdown]
# ### Task 5: Model Testing
# Test the model on a new dataset and evaluate its performance. You can use a subset of the dataset that you created or create a new one.

# %%
# Your code goes here
test_df = pd.DataFrame()
predictions = []
for _, row in df_emails.iterrows():
    row_dict = row.to_dict()
    predicted_class = bayes_classify(row_dict, df=df_emails)
    
    predictions.append(predicted_class)

predictions
# Out:
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24280896647490574
# Data after assigning len_cuts: {'email_length': -0.24280896647490574, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24340408649077566
# Data after assigning len_cuts: {'email_length': -0.24340408649077566, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24266018647093832
# Data after assigning len_cuts: {'email_length': -0.24266018647093832, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24176750644713352
# Data after assigning len_cuts: {'email_length': -0.24176750644713352, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2417179131124777
# Data after assigning len_cuts: {'email_length': -0.2417179131124777, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2425114064669708
# Data after assigning len_cuts: {'email_length': -0.2425114064669708, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437512398333664
# Data after assigning len_cuts: {'email_length': -0.2437512398333664, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24275937314024998
# Data after assigning len_cuts: {'email_length': -0.24275937314024998, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437512398333664
# Data after assigning len_cuts: {'email_length': -0.2437512398333664, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437512398333664
# Data after assigning len_cuts: {'email_length': -0.2437512398333664, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2430569331481849
# Data after assigning len_cuts: {'email_length': -0.2430569331481849, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24518944653838523
# Data after assigning len_cuts: {'email_length': -0.24518944653838523, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24499107319976196
# Data after assigning len_cuts: {'email_length': -0.24499107319976196, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24385042650267802
# Data after assigning len_cuts: {'email_length': -0.24385042650267802, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24429676651458046
# Data after assigning len_cuts: {'email_length': -0.24429676651458046, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2441975798452688
# Data after assigning len_cuts: {'email_length': -0.2441975798452688, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24469351319182703
# Data after assigning len_cuts: {'email_length': -0.24469351319182703, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24181709978178936
# Data after assigning len_cuts: {'email_length': -0.24181709978178936, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24469351319182703
# Data after assigning len_cuts: {'email_length': -0.24469351319182703, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2438008331680222
# Data after assigning len_cuts: {'email_length': -0.2438008331680222, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24315611981749652
# Data after assigning len_cuts: {'email_length': -0.24315611981749652, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24444554651854788
# Data after assigning len_cuts: {'email_length': -0.24444554651854788, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2429081531442174
# Data after assigning len_cuts: {'email_length': -0.2429081531442174, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24390001983733386
# Data after assigning len_cuts: {'email_length': -0.24390001983733386, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2435528664947431
# Data after assigning len_cuts: {'email_length': -0.2435528664947431, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24390001983733386
# Data after assigning len_cuts: {'email_length': -0.24390001983733386, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24142035310454277
# Data after assigning len_cuts: {'email_length': -0.24142035310454277, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.243304899821464
# Data after assigning len_cuts: {'email_length': -0.243304899821464, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24434635984923628
# Data after assigning len_cuts: {'email_length': -0.24434635984923628, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24449513985320373
# Data after assigning len_cuts: {'email_length': -0.24449513985320373, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2430569331481849
# Data after assigning len_cuts: {'email_length': -0.2430569331481849, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24523903987304108
# Data after assigning len_cuts: {'email_length': -0.24523903987304108, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2445943265225154
# Data after assigning len_cuts: {'email_length': -0.2445943265225154, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24310652648284073
# Data after assigning len_cuts: {'email_length': -0.24310652648284073, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24256099980162665
# Data after assigning len_cuts: {'email_length': -0.24256099980162665, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24310652648284073
# Data after assigning len_cuts: {'email_length': -0.24310652648284073, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24340408649077566
# Data after assigning len_cuts: {'email_length': -0.24340408649077566, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24360245982939893
# Data after assigning len_cuts: {'email_length': -0.24360245982939893, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24474310652648282
# Data after assigning len_cuts: {'email_length': -0.24474310652648282, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24399920650664553
# Data after assigning len_cuts: {'email_length': -0.24399920650664553, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437512398333664
# Data after assigning len_cuts: {'email_length': -0.2437512398333664, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2422138464590359
# Data after assigning len_cuts: {'email_length': -0.2422138464590359, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24504066653441775
# Data after assigning len_cuts: {'email_length': -0.24504066653441775, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24365205316405475
# Data after assigning len_cuts: {'email_length': -0.24365205316405475, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24394961317198968
# Data after assigning len_cuts: {'email_length': -0.24394961317198968, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24266018647093832
# Data after assigning len_cuts: {'email_length': -0.24266018647093832, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24226343979369172
# Data after assigning len_cuts: {'email_length': -0.24226343979369172, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24236262646300338
# Data after assigning len_cuts: {'email_length': -0.24236262646300338, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24409839317595713
# Data after assigning len_cuts: {'email_length': -0.24409839317595713, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24360245982939893
# Data after assigning len_cuts: {'email_length': -0.24360245982939893, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24231303312834754
# Data after assigning len_cuts: {'email_length': -0.24231303312834754, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437512398333664
# Data after assigning len_cuts: {'email_length': -0.2437512398333664, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24345367982543145
# Data after assigning len_cuts: {'email_length': -0.24345367982543145, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24439595318389212
# Data after assigning len_cuts: {'email_length': -0.24439595318389212, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24444554651854788
# Data after assigning len_cuts: {'email_length': -0.24444554651854788, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24191628645110097
# Data after assigning len_cuts: {'email_length': -0.24191628645110097, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24335449315611982
# Data after assigning len_cuts: {'email_length': -0.24335449315611982, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24226343979369172
# Data after assigning len_cuts: {'email_length': -0.24226343979369172, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2429081531442174
# Data after assigning len_cuts: {'email_length': -0.2429081531442174, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24390001983733386
# Data after assigning len_cuts: {'email_length': -0.24390001983733386, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2429081531442174
# Data after assigning len_cuts: {'email_length': -0.2429081531442174, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24176750644713352
# Data after assigning len_cuts: {'email_length': -0.24176750644713352, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.243304899821464
# Data after assigning len_cuts: {'email_length': -0.243304899821464, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2417179131124777
# Data after assigning len_cuts: {'email_length': -0.2417179131124777, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24588375322356676
# Data after assigning len_cuts: {'email_length': -0.24588375322356676, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2435528664947431
# Data after assigning len_cuts: {'email_length': -0.2435528664947431, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24523903987304108
# Data after assigning len_cuts: {'email_length': -0.24523903987304108, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2429081531442174
# Data after assigning len_cuts: {'email_length': -0.2429081531442174, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24181709978178936
# Data after assigning len_cuts: {'email_length': -0.24181709978178936, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2438008331680222
# Data after assigning len_cuts: {'email_length': -0.2438008331680222, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24409839317595713
# Data after assigning len_cuts: {'email_length': -0.24409839317595713, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2438008331680222
# Data after assigning len_cuts: {'email_length': -0.2438008331680222, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24236262646300338
# Data after assigning len_cuts: {'email_length': -0.24236262646300338, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2438008331680222
# Data after assigning len_cuts: {'email_length': -0.2438008331680222, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24275937314024998
# Data after assigning len_cuts: {'email_length': -0.24275937314024998, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24231303312834754
# Data after assigning len_cuts: {'email_length': -0.24231303312834754, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24399920650664553
# Data after assigning len_cuts: {'email_length': -0.24399920650664553, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24360245982939893
# Data after assigning len_cuts: {'email_length': -0.24360245982939893, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24365205316405475
# Data after assigning len_cuts: {'email_length': -0.24365205316405475, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24474310652648282
# Data after assigning len_cuts: {'email_length': -0.24474310652648282, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24325530648680818
# Data after assigning len_cuts: {'email_length': -0.24325530648680818, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24469351319182703
# Data after assigning len_cuts: {'email_length': -0.24469351319182703, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2437016464987106
# Data after assigning len_cuts: {'email_length': -0.2437016464987106, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24360245982939893
# Data after assigning len_cuts: {'email_length': -0.24360245982939893, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24409839317595713
# Data after assigning len_cuts: {'email_length': -0.24409839317595713, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24345367982543145
# Data after assigning len_cuts: {'email_length': -0.24345367982543145, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24285855980956159
# Data after assigning len_cuts: {'email_length': -0.24285855980956159, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24142035310454277
# Data after assigning len_cuts: {'email_length': -0.24142035310454277, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24310652648284073
# Data after assigning len_cuts: {'email_length': -0.24310652648284073, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24335449315611982
# Data after assigning len_cuts: {'email_length': -0.24335449315611982, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24518944653838523
# Data after assigning len_cuts: {'email_length': -0.24518944653838523, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.243304899821464
# Data after assigning len_cuts: {'email_length': -0.243304899821464, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2408252330886729
# Data after assigning len_cuts: {'email_length': -0.2408252330886729, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24345367982543145
# Data after assigning len_cuts: {'email_length': -0.24345367982543145, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.243304899821464
# Data after assigning len_cuts: {'email_length': -0.243304899821464, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24444554651854788
# Data after assigning len_cuts: {'email_length': -0.24444554651854788, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24216425312438006
# Data after assigning len_cuts: {'email_length': -0.24216425312438006, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2425114064669708
# Data after assigning len_cuts: {'email_length': -0.2425114064669708, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2425114064669708
# Data after assigning len_cuts: {'email_length': -0.2425114064669708, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2441975798452688
# Data after assigning len_cuts: {'email_length': -0.2441975798452688, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24186669311644513
# Data after assigning len_cuts: {'email_length': -0.24186669311644513, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24469351319182703
# Data after assigning len_cuts: {'email_length': -0.24469351319182703, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24270977980559413
# Data after assigning len_cuts: {'email_length': -0.24270977980559413, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24112279309660783
# Data after assigning len_cuts: {'email_length': -0.24112279309660783, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24424717317992461
# Data after assigning len_cuts: {'email_length': -0.24424717317992461, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24385042650267802
# Data after assigning len_cuts: {'email_length': -0.24385042650267802, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2438008331680222
# Data after assigning len_cuts: {'email_length': -0.2438008331680222, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24484229319579448
# Data after assigning len_cuts: {'email_length': -0.24484229319579448, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24320571315215234
# Data after assigning len_cuts: {'email_length': -0.24320571315215234, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24434635984923628
# Data after assigning len_cuts: {'email_length': -0.24434635984923628, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24280896647490574
# Data after assigning len_cuts: {'email_length': -0.24280896647490574, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2441975798452688
# Data after assigning len_cuts: {'email_length': -0.2441975798452688, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24176750644713352
# Data after assigning len_cuts: {'email_length': -0.24176750644713352, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24404879984130134
# Data after assigning len_cuts: {'email_length': -0.24404879984130134, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24360245982939893
# Data after assigning len_cuts: {'email_length': -0.24360245982939893, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24449513985320373
# Data after assigning len_cuts: {'email_length': -0.24449513985320373, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2430569331481849
# Data after assigning len_cuts: {'email_length': -0.2430569331481849, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2419658797857568
# Data after assigning len_cuts: {'email_length': -0.2419658797857568, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2448918865304503
# Data after assigning len_cuts: {'email_length': -0.2448918865304503, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24310652648284073
# Data after assigning len_cuts: {'email_length': -0.24310652648284073, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2425114064669708
# Data after assigning len_cuts: {'email_length': -0.2425114064669708, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24449513985320373
# Data after assigning len_cuts: {'email_length': -0.24449513985320373, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2445943265225154
# Data after assigning len_cuts: {'email_length': -0.2445943265225154, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24275937314024998
# Data after assigning len_cuts: {'email_length': -0.24275937314024998, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24394961317198968
# Data after assigning len_cuts: {'email_length': -0.24394961317198968, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2430569331481849
# Data after assigning len_cuts: {'email_length': -0.2430569331481849, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24399920650664553
# Data after assigning len_cuts: {'email_length': -0.24399920650664553, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24142035310454277
# Data after assigning len_cuts: {'email_length': -0.24142035310454277, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24280896647490574
# Data after assigning len_cuts: {'email_length': -0.24280896647490574, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24444554651854788
# Data after assigning len_cuts: {'email_length': -0.24444554651854788, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24261059313628247
# Data after assigning len_cuts: {'email_length': -0.24261059313628247, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24424717317992461
# Data after assigning len_cuts: {'email_length': -0.24424717317992461, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.2425114064669708
# Data after assigning len_cuts: {'email_length': -0.2425114064669708, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'evening', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24211465978972427
# Data after assigning len_cuts: {'email_length': -0.24211465978972427, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'afternoon', 'label': 'ham', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24409839317595713
# Data after assigning len_cuts: {'email_length': -0.24409839317595713, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24231303312834754
# Data after assigning len_cuts: {'email_length': -0.24231303312834754, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24285855980956159
# Data after assigning len_cuts: {'email_length': -0.24285855980956159, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24142035310454277
# Data after assigning len_cuts: {'email_length': -0.24142035310454277, 'contains_free': 0, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'large'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24350327316008727
# Data after assigning len_cuts: {'email_length': -0.24350327316008727, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'night', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24404879984130134
# Data after assigning len_cuts: {'email_length': -0.24404879984130134, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24414798651061295
# Data after assigning len_cuts: {'email_length': -0.24414798651061295, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24409839317595713
# Data after assigning len_cuts: {'email_length': -0.24409839317595713, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'night', 'label': 'ham', 'len_cuts': 'small'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24335449315611982
# Data after assigning len_cuts: {'email_length': -0.24335449315611982, 'contains_free': 1, 'contains_winner': 0, 'time_of_day': 'morning', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24295774647887325
# Data after assigning len_cuts: {'email_length': -0.24295774647887325, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'morning', 'label': 'spam', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24300733981352907
# Data after assigning len_cuts: {'email_length': -0.24300733981352907, 'contains_free': 0, 'contains_winner': 0, 'time_of_day': 'evening', 'label': 'ham', 'len_cuts': 'medium'}
# length divisions [0.         0.38732394 0.51408451 1.        ]
# email length -0.24246181313231505
# Data after assigning len_cuts: {'email_length': -0.24246181313231505, 'contains_free': 1, 'contains_winner': 1, 'time_of_day': 'afternoon', 'label': 'spam', 'len_cuts': 'large'}
# ...
#  0.8118952204519599,
#  0.8404068990263758,
#  0.973436523293239,
#  0.807235884282403,
#  0.7744380456419202,
#  0.7803394193199706,
#  0.7715833971047873,
#  0.1952168640392154,
#  0.7013036126226159,
#  0.2587605180978532,
#  0.2224739139197443,
#  0.2224739139197443,
#  0.6722947542092659,
#  0.19061268008564278,
#  0.981386070316162,
#  0.968697723547009,
#  0.22314565232199796,
#  0.8316411214314678,
#  0.7803394193199706,
#  0.22314565232199796,
#  0.6722947542092659,
#  0.974197643187433,
#  0.8169927245212176,
#  0.7854136670309722,
#  0.7715833971047873,
#  0.19061268008564278,
#  0.7532598984231302,
#  0.1952168640392154,
#  0.2587605180978532,
#  0.19526096686971828,
#  0.836362122521223,
#  0.812486936020514,
#  0.19061268008564278,
#  0.8316411214314678,
#  0.7411816275942578,
#  0.7145260913282749,
#  0.22314565232199796,
#  0.8169927245212176,
#  0.7853663553460483,
#  0.8118952204519599,
#  0.25307597552275124,
#  0.7803394193199706,
#  0.2224739139197443,
#  0.7803394193199706,
#  0.807235884282403,
#  0.24668404856416695,
#  0.9781166161452991,
#  0.749999913547945,
#  0.22836345053971946,
#  0.7803394193199706,
#  0.19061268008564278,
#  0.9819236425996397,
#  0.812486936020514,
#  0.974197643187433,
#  0.8118952204519599,
#  0.807235884282403,
#  0.7469370469466098,
#  0.8316411214314678,
#  0.19526096686971828,
#  0.18540677432428695,
#  0.2224739139197443,
#  0.7715833971047873,
#  0.8169927245212176,
#  0.21728975886903232,
#  0.836362122521223,
#  0.16588622382703366,
#  0.25307597552275124,
#  0.8169927245212176,
#  0.21728975886903232,
#  0.7775380028663664,
#  0.836362122521223,
#  0.24668404856416695,
#  0.98075276677186,
#  0.1952168640392154,
#  0.25307597552275124,
#  0.812486936020514,
#  0.22836345053971946,
#  0.1952168640392154,
#  0.7532598984231302,
#  0.25307597552275124,
#  0.7854136670309722,
#  0.7775380028663664,
#  0.7803394193199706,
#  0.7854136670309722,
#  0.2587605180978532,
#  0.98075276677186,
#  0.24668404856416695,
#  0.8316411214314678,
#  0.22314565232199796,
#  0.7854136670309722,
#  0.1952168640392154,
#  0.19061268008564278,
#  0.9780334302569007,
#  0.8169927245212176,
#  0.19061268008564278,
#  0.7144688323263281,
#  0.9741905865570585,
#  0.7744380456419202,
#  0.7744380456419202,
#  0.807235884282403,
#  0.9781166161452991,
#  0.974197643187433,
#  0.19526096686971828,
#  0.7411816275942578,
#  0.7744380456419202,
#  0.7744380456419202,
#  0.16588622382703366,
#  0.7411816275942578,
#  0.7853663553460483,
#  0.9819236425996397,
#  0.7775380028663664,
#  0.7476695932298133,
#  0.22314565232199796,
#  0.19061268008564278,
#  0.1952168640392154,
#  0.1952168640392154,
#  0.807235884282403,
#  0.6722947542092659,
#  0.8316411214314678,
#  0.8316411214314678,
#  0.22314565232199796,
#  0.7853663553460483,
#  0.2224739139197443,
#  0.807235884282403,
#  0.7411816275942578,
#  0.8169927245212176,
#  0.9787465657569145,
#  0.7013036126226159,
#  0.22836345053971946,
#  0.9819236425996397,
#  0.8316411214314678,
#  0.7715833971047873,
#  0.8118952204519599,
#  0.7013036126226159,
#  0.98075276677186,
#  0.7476695932298133,
#  0.9780334302569007,
#  0.16588622382703366,
#  0.16588622382703366,
#  0.19061268008564278,
#  0.18540677432428695,
#  0.749999913547945,
#  0.16588622382703366,
#  0.9787465657569145,
#  0.1952168640392154,
#  0.7715833971047873,
#  0.24668404856416695,
#  0.7145260913282749,
#  0.6722947542092659,
#  0.2224739139197443,
#  0.16588622382703366,
#  0.7775380028663664,
#  0.8118952204519599,
#  0.7744380456419202,
#  0.18540677432428695,
#  0.25307597552275124,
#  0.812486936020514,
#  0.8118952204519599,
#  0.7854136670309722,
#  0.19061268008564278,
#  0.9781166161452991,
#  0.7853663553460483,
#  0.968697723547009,
#  0.836362122521223,
#  0.19526096686971828,
#  0.22314565232199796,
#  0.7853663553460483,
#  0.8118952204519599,
#  0.25307597552275124,
#  0.19526096686971828,
#  0.19061268008564278,
#  0.25307597552275124,
#  0.7853663553460483,
#  0.7854136670309722,
#  0.7715833971047873,
#  0.22836345053971946,
#  0.25307597552275124,
#  0.7476695932298133,
#  0.836362122521223,
#  0.8404068990263758,
#  0.9741905865570585,
#  0.25307597552275124,
#  0.836362122521223,
#  0.8404068990263758,
#  0.7744380456419202,
#  0.24668404856416695,
#  0.2224739139197443,
#  0.16588622382703366,
#  0.19061268008564278,
#  0.7145260913282749,
#  0.7476695932298133,
#  0.2224739139197443,
#  0.8404068990263758,
#  0.22836345053971946,
#  0.2224739139197443,
#  0.7744380456419202,
#  0.7744380456419202,
#  0.9787465657569145,
#  0.812486936020514,
#  0.807235884282403,
#  0.7803394193199706,
#  0.21728975886903232,
#  0.7013036126226159,
#  0.7775380028663664,
#  0.7144688323263281,
#  0.18540677432428695,
#  0.7744380456419202,
#  0.7803394193199706,
#  0.7853663553460483,
#  0.24668404856416695,
#  0.9725403193735386,
#  0.8118952204519599,
#  0.18540677432428695,
#  0.749999913547945,
#  0.1952168640392154,
#  0.19061268008564278,
#  0.974197643187433,
#  0.6722947542092659,
#  0.7775380028663664,
#  0.8169927245212176,
#  0.7744380456419202,
#  0.22836345053971946,
#  0.1952168640392154,
#  0.7144688323263281,
#  0.8118952204519599,
#  0.2224739139197443,
#  0.16588622382703366,
#  0.7803394193199706,
#  0.9741905865570585,
#  0.19061268008564278,
#  0.7744380456419202,
#  0.8118952204519599,
#  0.2224739139197443,
#  0.7532598984231302,
#  0.98075276677186,
#  0.7144688323263281,
#  0.9780334302569007,
#  0.24668404856416695,
#  0.22314565232199796,
#  0.16588622382703366,
#  0.19526096686971828,
#  0.7144688323263281,
#  0.19526096686971828,
#  0.974197643187433,
#  0.749999913547945,
#  0.749999913547945,
#  0.8404068990263758,
#  0.7715833971047873,
#  0.807235884282403,
#  0.2224739139197443,
#  0.812486936020514,
#  0.7744380456419202,
#  0.8118952204519599,
#  0.98075276677186,
#  0.7803394193199706,
#  0.1952168640392154,
#  0.19061268008564278,
#  0.749999913547945,
#  0.7775380028663664,
#  0.8316411214314678,
#  0.7744380456419202,
#  0.25307597552275124,
#  0.973436523293239,
#  0.973436523293239,
#  0.749999913547945,
#  0.7744380456419202,
#  0.7853663553460483,
#  0.9725403193735386,
#  0.8169927245212176,
#  0.1952168640392154,
#  0.21728975886903232,
#  0.7744380456419202,
#  0.16588622382703366,
#  0.9780334302569007,
#  0.8316411214314678,
#  0.16588622382703366,
#  0.812486936020514,
#  0.9780334302569007,
#  0.16588622382703366,
#  0.7469370469466098,
#  0.18540677432428695,
#  0.25307597552275124,
#  0.7854136670309722,
#  0.19526096686971828,
#  0.7803394193199706,
#  0.7476695932298133,
#  0.22314565232199796,
#  0.7744380456419202,
#  0.8404068990263758,
#  0.7083979359443652,
#  0.7411816275942578,
#  0.19526096686971828,
#  0.6722947542092659,
#  0.807235884282403,
#  0.19526096686971828,
#  0.7411816275942578,
#  0.7826589402464167,
#  0.7854136670309722,
#  0.8118952204519599,
#  0.18540677432428695,
#  0.981386070316162,
#  0.2224739139197443,
#  0.16588622382703366,
#  0.7854136670309722,
#  0.836362122521223,
#  0.807235884282403,
#  0.9781166161452991,
#  0.19061268008564278,
#  0.812486936020514,
#  0.22314565232199796,
#  0.981386070316162,
#  0.22836345053971946,
#  0.8169927245212176,
#  0.7144688323263281,
#  0.7145260913282749,
#  0.9741905865570585,
#  0.7144688323263281,
#  0.807235884282403,
#  0.7476695932298133,
#  0.2587605180978532,
#  0.7715833971047873,
#  0.7532598984231302,
#  0.9780334302569007,
#  0.22836345053971946,
#  0.7803394193199706,
#  0.749999913547945,
#  0.6722947542092659,
#  0.9773746401548492,
#  0.812486936020514,
#  0.8118952204519599,
#  0.22314565232199796,
#  0.7532598984231302,
#  0.981386070316162,
#  0.749999913547945,
#  0.807235884282403,
#  0.7469370469466098,
#  0.973436523293239,
#  0.25307597552275124,
#  0.1952168640392154,
#  0.22314565232199796,
#  0.8404068990263758,
#  0.2224739139197443,
#  0.21728975886903232,
#  0.9741905865570585,
#  0.19526096686971828,
#  0.7145260913282749,
#  0.2587605180978532,
#  0.7854136670309722,
#  0.8169927245212176,
#  0.18540677432428695,
#  0.981386070316162,
#  0.9787465657569145,
#  0.2587605180978532,
#  0.749999913547945,
#  0.9773746401548492,
#  0.7744380456419202,
#  0.22314565232199796,
#  0.9773746401548492,
#  0.8118952204519599,
#  0.16588622382703366,
#  0.25307597552275124,
#  0.7469370469466098,
#  0.22836345053971946,
#  0.8404068990263758,
#  0.6722947542092659,
#  0.19061268008564278,
#  0.9725403193735386,
#  0.25307597552275124,
#  0.98075276677186,
#  0.1952168640392154,
#  0.1952168640392154,
#  0.19526096686971828,
#  0.24668404856416695,
#  0.7476695932298133,
#  0.9741905865570585,
#  0.836362122521223,
#  0.2587605180978532,
#  0.9773746401548492,
#  0.9725403193735386,
#  0.8118952204519599,
#  0.24668404856416695,
#  0.2224739139197443,
#  0.2587605180978532,
#  0.7744380456419202,
#  0.749999913547945,
#  0.22314565232199796,
#  0.7144688323263281,
#  0.8316411214314678,
#  0.7854136670309722,
#  0.8316411214314678,
#  0.807235884282403,
#  0.1952168640392154,
#  0.7803394193199706,
#  0.7744380456419202,
#  0.25307597552275124,
#  0.7853663553460483,
#  0.7803394193199706,
#  0.6722947542092659,
#  0.8169927245212176,
#  0.981386070316162,
#  0.812486936020514,
#  0.19526096686971828,
#  0.22314565232199796,
#  0.8169927245212176,
#  0.7013036126226159,
#  0.9741905865570585,
#  0.9787465657569145,
#  0.25307597552275124,
#  0.8404068990263758,
#  0.836362122521223,
#  0.21728975886903232,
#  0.7854136670309722,
#  0.8316411214314678,
#  0.7853663553460483,
#  0.812486936020514,
#  0.7476695932298133,
#  0.9773746401548492,
#  0.9741905865570585,
#  0.7854136670309722,
#  0.7854136670309722,
#  0.22314565232199796,
#  0.9725403193735386,
#  0.18540677432428695,
#  0.22836345053971946,
#  0.7144688323263281,
#  0.8118952204519599,
#  0.7854136670309722,
#  0.8404068990263758,
#  0.8316411214314678,
#  0.749999913547945,
#  0.8169927245212176,
#  0.22836345053971946,
#  0.19061268008564278,
#  0.7145260913282749,
#  0.7854136670309722,
#  0.8118952204519599,
#  0.24668404856416695,
#  0.7469370469466098,
#  0.8316411214314678,
#  0.19061268008564278,
#  0.974197643187433,
#  0.981386070316162,
#  0.18540677432428695,
#  0.7469370469466098,
#  0.7853663553460483,
#  0.812486936020514,
#  0.8316411214314678,
#  0.812486936020514,
#  0.7476695932298133,
#  0.8404068990263758,
#  0.7803394193199706,
#  0.9819236425996397,
#  0.7826589402464167,
#  0.7853663553460483,
#  0.8169927245212176,
#  0.19526096686971828,
#  0.7469370469466098,
#  0.812486936020514,
#  0.7013036126226159,
#  0.24668404856416695,
#  0.18540677432428695,
#  0.7803394193199706,
#  0.7854136670309722,
#  0.8316411214314678,
#  0.7083979359443652,
#  0.8404068990263758,
#  0.749999913547945,
#  0.98075276677186,
#  0.8169927245212176,
#  0.7411816275942578,
#  0.7744380456419202,
#  0.21728975886903232,
#  0.8169927245212176,
#  0.25307597552275124,
#  0.7532598984231302,
#  0.21728975886903232,
#  0.8169927245212176,
#  0.1952168640392154,
#  0.812486936020514,
#  0.7145260913282749,
#  0.16588622382703366,
#  0.836362122521223,
#  0.7144688323263281,
#  0.22314565232199796,
#  0.9787465657569145,
#  0.1952168640392154,
#  0.18540677432428695,
#  0.16588622382703366,
#  0.9781166161452991,
#  0.974197643187433,
#  0.812486936020514,
#  0.749999913547945,
#  0.2224739139197443,
#  0.24668404856416695,
#  0.8169927245212176,
#  0.7826589402464167,
#  0.2224739139197443,
#  0.2587605180978532,
#  0.18540677432428695,
#  0.7803394193199706,
#  0.19526096686971828,
#  0.7853663553460483,
#  0.7775380028663664,
#  0.7803394193199706,
#  0.21728975886903232,
#  0.16588622382703366,
#  0.974197643187433,
#  0.968697723547009,
#  0.19061268008564278,
#  0.6722947542092659,
#  0.19526096686971828,
#  0.2587605180978532,
#  0.18540677432428695,
#  0.2587605180978532,
#  0.2587605180978532,
#  0.7144688323263281,
#  0.968697723547009,
#  0.836362122521223,
#  0.7744380456419202,
#  0.1952168640392154,
#  0.2587605180978532,
#  0.812486936020514,
#  0.2224739139197443,
#  0.18540677432428695,
#  0.9773746401548492,
#  0.836362122521223,
#  0.7803394193199706,
#  0.7775380028663664,
#  0.25307597552275124,
#  0.7803394193199706,
#  0.2587605180978532,
#  0.8404068990263758,
#  0.9780334302569007,
#  0.7744380456419202,
#  0.19526096686971828,
#  0.7532598984231302,
#  0.9787465657569145,
#  0.9780334302569007,
#  0.812486936020514,
#  0.16588622382703366,
#  0.7411816275942578,
#  0.98075276677186,
#  0.8316411214314678,
#  0.8316411214314678,
#  0.2587605180978532,
#  0.9819236425996397,
#  0.7853663553460483,
#  0.7803394193199706,
#  0.21728975886903232,
#  0.1952168640392154,
#  0.9787465657569145,
#  0.19526096686971828,
#  0.7083979359443652,
#  0.981386070316162,
#  0.22314565232199796,
#  0.8118952204519599,
#  0.22836345053971946,
#  0.9787465657569145,
#  0.836362122521223,
#  0.18540677432428695,
#  0.7476695932298133,
#  0.16588622382703366,
#  0.7476695932298133,
#  0.812486936020514,
#  0.7853663553460483,
#  0.19061268008564278,
#  0.7826589402464167,
#  0.18540677432428695,
#  0.9781166161452991,
#  0.7144688323263281,
#  0.8316411214314678,
#  0.9741905865570585,
#  0.8316411214314678,
#  0.18540677432428695,
#  0.812486936020514,
#  0.7826589402464167,
#  0.22314565232199796,
#  0.8118952204519599,
#  0.749999913547945,
#  0.24668404856416695,
#  0.24668404856416695,
#  0.7532598984231302,
#  0.7476695932298133,
#  0.2224739139197443,
#  0.7715833971047873,
#  0.19526096686971828,
#  0.9741905865570585,
#  0.807235884282403,
#  0.749999913547945,
#  0.19526096686971828,
#  0.974197643187433,
#  0.749999913547945,
#  0.812486936020514,
#  0.7853663553460483,
#  0.8316411214314678,
#  0.7803394193199706,
#  0.7715833971047873,
#  0.9741905865570585,
#  0.812486936020514,
#  0.98075276677186,
#  0.749999913547945,
#  0.7144688323263281,
#  0.7476695932298133,
#  0.8118952204519599,
#  0.9787465657569145,
#  0.8316411214314678,
#  0.18540677432428695,
#  0.6722947542092659,
#  0.749999913547945,
#  0.7854136670309722,
#  0.7803394193199706,
#  0.7469370469466098,
#  0.8118952204519599,
#  0.16588622382703366,
#  0.968697723547009,
#  0.7715833971047873,
#  0.16588622382703366,
#  0.8316411214314678,
#  0.7853663553460483,
#  0.19061268008564278,
#  0.8404068990263758,
#  0.7775380028663664,
#  0.16588622382703366,
#  0.1952168640392154,
#  0.1952168640392154,
#  0.9781166161452991,
#  0.2224739139197443,
#  0.7775380028663664,
#  0.807235884282403,
#  0.19526096686971828,
#  0.7854136670309722,
#  0.19061268008564278,
#  0.807235884282403,
#  0.25307597552275124,
#  0.18540677432428695,
#  0.7144688323263281,
#  0.21728975886903232,
#  0.7715833971047873,
#  0.8316411214314678,
#  0.7854136670309722,
#  0.7744380456419202,
#  0.8118952204519599,
#  0.2224739139197443,
#  0.2224739139197443,
#  0.24668404856416695,
#  0.22314565232199796,
#  0.836362122521223,
#  0.9780334302569007,
#  0.7826589402464167,
#  0.7775380028663664,
#  0.98075276677186,
#  0.836362122521223,
#  0.2224739139197443,
#  0.9819236425996397,
#  0.812486936020514,
#  0.22314565232199796,
#  0.2224739139197443,
#  0.7854136670309722,
#  0.8169927245212176,
#  0.9741905865570585,
#  0.21728975886903232,
#  0.25307597552275124,
#  0.9773746401548492,
#  0.812486936020514,
#  0.19061268008564278,
#  0.8316411214314678,
#  0.9780334302569007,
#  0.9780334302569007,
#  0.812486936020514,
#  0.9741905865570585,
#  0.22314565232199796,
#  0.9780334302569007,
#  0.7476695932298133,
#  0.9741905865570585,
#  0.2587605180978532,
#  0.9773746401548492,
#  0.7532598984231302,
#  0.21728975886903232,
#  0.7715833971047873,
#  0.19061268008564278,
#  0.9773746401548492,
#  0.7854136670309722,
#  0.9819236425996397,
#  0.16588622382703366,
#  0.19526096686971828,
#  0.1952168640392154,
#  0.24668404856416695,
#  0.8169927245212176,
#  0.18540677432428695,
#  0.2587605180978532,
#  0.19526096686971828,
#  0.16588622382703366,
#  0.9773746401548492,
#  0.7854136670309722,
#  0.7083979359443652,
#  0.7715833971047873,
#  0.21728975886903232,
#  0.18540677432428695,
#  0.6722947542092659,
#  0.836362122521223,
#  0.8316411214314678,
#  0.8169927245212176,
#  0.7826589402464167,
#  0.16588622382703366,
#  0.7854136670309722,
#  0.9725403193735386,
#  0.9787465657569145,
#  0.21728975886903232,
#  0.8169927245212176,
#  0.7476695932298133,
#  0.749999913547945,
#  0.8118952204519599,
#  0.812486936020514,
#  0.7775380028663664,
#  0.7853663553460483,
#  0.7775380028663664,
#  0.7715833971047873,
#  0.22836345053971946,
#  0.8118952204519599,
#  0.25307597552275124,
#  0.21728975886903232,
#  0.8118952204519599,
#  0.7476695932298133,
#  0.8118952204519599,
#  0.7083979359443652,
#  0.2224739139197443,
#  0.807235884282403,
#  0.18540677432428695,
#  0.22836345053971946,
#  0.968697723547009,
#  0.8404068990263758,
#  0.749999913547945,
#  0.22314565232199796,
#  0.19061268008564278,
#  0.7854136670309722,
#  0.749999913547945,
#  0.974197643187433,
#  0.8316411214314678,
#  0.9819236425996397,
#  0.22836345053971946,
#  0.19061268008564278,
#  0.8169927245212176,
#  0.1952168640392154,
#  0.19061268008564278,
#  0.8404068990263758,
#  0.8316411214314678,
#  0.22836345053971946,
#  0.22836345053971946,
#  0.7532598984231302,
#  0.7803394193199706,
#  0.7853663553460483,
#  0.18540677432428695,
#  0.19526096686971828,
#  0.7853663553460483,
#  0.2224739139197443,
#  0.836362122521223,
#  0.7744380456419202,
#  0.25307597552275124]

# %% [markdown]
# ### Task 6: Discussion
# 1. Discuss how Bayesian updating improves the accuracy of the classifier.
# 2. What are the limitations of the model built in this lab?

# %% [markdown]
# ### Answers
# 1. Bayesian updating allows us to continuously improve our model as new data becomes available. By updating the prior probabilities with new evidence, we can refine our predictions and make them more accurate. This iterative process helps in incorporating new information and adjusting the model to better reflect the underlying patterns in the data. In the context of our email classifier, Bayesian updating helps in dynamically adjusting the probabilities of an email being spam or ham based on the features observed in the new emails.
#
# 2.  - Simplistic Assumptions: The model assumes that the features are independent of each other, which might not be true in real-world scenarios. This is known as the "naive" assumption in Naive Bayes classifiers.
#     - Feature Engineering: The model's performance heavily depends on the quality and relevance of the features used. If important features are missing or irrelevant features are included, the model's accuracy can be affected.
#     - Static Model: The model does not adapt to changes in the data distribution over time unless explicitly updated with new data.

# %% [markdown]
# ## Submission
# Submit a link to your completed Jupyter Notebook file hosted on your private GitHub repository through the submission link in Blackboard.
