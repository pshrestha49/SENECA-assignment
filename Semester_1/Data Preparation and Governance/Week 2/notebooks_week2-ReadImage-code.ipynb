# %%
# AIG150 Winter 2024
# Week 2 Sample Code 
# Asma M Paracha
# unstructured file

# %%
# the necessary imports
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %%
# reading the image file and print it on screen
example_file = ("Dog_face.png")
image = imread(example_file)
plt.imshow(image)
plt.show()

# %%
# print the type and size of data
print("data type: %s, shape: %s" % (type(image), image.shape))
# Out:
# data type: <class 'numpy.ndarray'>, shape: (90, 90, 3)

# %%
# crop the image and then print it
image2 = image[5:70,0:70]
plt.imshow(image2)
plt.show()
