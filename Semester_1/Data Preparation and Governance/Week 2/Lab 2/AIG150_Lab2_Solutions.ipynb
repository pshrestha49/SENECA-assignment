# %% [markdown]
# # Lab 2
# Data Loading, Storage, Cleaning and Assembly with Python
# ### Learning objectives
# Upon successful completion of this lab, you will have demonstrated the abilities to:
# 1. Manipulating data streams
# 2. Working with flat and structured files
# 3. Interacting with relational databases
# 4. Interacting with web-based data
# 5. Merging multiple datasets
# 6. Working with untidy data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Load customer.csv file into dataframe customer, print the data.

# %%
customer = pd.read_csv('customer.csv', index_col=0)
customer.head()
# Out:
#    CUS_CODE CUS_LNAME CUS_FNAME
# 0     10010     Ramas    Alfred
# 1     10011     Dunne     Leona
# 2     10012     Smith     Kathy
# 3     10013   Olowski      Paul
# 4     10014   Orlando     Myron

# %% [markdown]
# 2. Load invoice.csv file into dataframe invoice, print the data.

# %%
invoice = pd.read_csv('invoice.csv', index_col=0)
invoice.head()
# Out:
#    INV_NUMBER  CUS_CODE    INV_DATE
# 0        1001     10014  2012-01-16
# 1        1002     10011  2012-01-16
# 2        1003     10012  2012-01-16
# 3        1004     10011  2012-01-17
# 4        1005     10018  2012-01-17

# %% [markdown]
# 3. Count the number of invoices per customer form the invoice dataframe. Hint: call value_counts() function on CUS_CODE in dataframe invoice and print the result. value_counts() returns a dictionary of the list of unique values and the frequency of each.

# %%
invoice['CUS_CODE'].value_counts()
# Out:
# CUS_CODE
# 10011    3
# 10014    2
# 10012    1
# 10018    1
# 10015    1
# Name: count, dtype: int64

# %% [markdown]
# 4. Add the following row in dataframe customer: 10020 Smith James that correspond to customer code, last name and first name respectively. Then print dataframe customer.

# %%
customer.loc[len(customer)] = [10020, 'Smith', 'James']
print(customer)
# Out:
#     CUS_CODE CUS_LNAME CUS_FNAME
# 0      10010     Ramas    Alfred
# 1      10011     Dunne     Leona
# 2      10012     Smith     Kathy
# 3      10013   Olowski      Paul
# 4      10014   Orlando     Myron
# 5      10015   O'Brian       Amy
# 6      10016     Brown     James
# 7      10017  Williams    George
# 8      10018   Farriss      Anne
# 9      10019     Smith    Olette
# 10     10020     Smith     James

# %% [markdown]
# 5. Merge the customer and invoice dataframes and show all customers from dataframe customer.

# %%
customer_invoice = pd.merge(customer, invoice, on='CUS_CODE', how='left')
customer_invoice
# Out:
#     CUS_CODE CUS_LNAME CUS_FNAME  INV_NUMBER    INV_DATE
# 0      10010     Ramas    Alfred         NaN         NaN
# 1      10011     Dunne     Leona      1002.0  2012-01-16
# 2      10011     Dunne     Leona      1004.0  2012-01-17
# 3      10011     Dunne     Leona      1008.0  2012-01-17
# 4      10012     Smith     Kathy      1003.0  2012-01-16
# 5      10013   Olowski      Paul         NaN         NaN
# 6      10014   Orlando     Myron      1001.0  2012-01-16
# 7      10014   Orlando     Myron      1006.0  2012-01-17
# 8      10015   O'Brian       Amy      1007.0  2012-01-17
# 9      10016     Brown     James         NaN         NaN
# 10     10017  Williams    George         NaN         NaN
# 11     10018   Farriss      Anne      1005.0  2012-01-17
# 12     10019     Smith    Olette         NaN         NaN
# 13     10020     Smith     James         NaN         NaN

# %% [markdown]
# 6. Merge the customer and invoice dataframes and show all matched and unmatched rows from both dataframes.

# %%
customer_invoice = pd.merge(customer, invoice, on='CUS_CODE', how='outer')
customer_invoice
# Out:
#     CUS_CODE CUS_LNAME CUS_FNAME  INV_NUMBER    INV_DATE
# 0      10010     Ramas    Alfred         NaN         NaN
# 1      10011     Dunne     Leona      1002.0  2012-01-16
# 2      10011     Dunne     Leona      1004.0  2012-01-17
# 3      10011     Dunne     Leona      1008.0  2012-01-17
# 4      10012     Smith     Kathy      1003.0  2012-01-16
# 5      10013   Olowski      Paul         NaN         NaN
# 6      10014   Orlando     Myron      1001.0  2012-01-16
# 7      10014   Orlando     Myron      1006.0  2012-01-17
# 8      10015   O'Brian       Amy      1007.0  2012-01-17
# 9      10016     Brown     James         NaN         NaN
# 10     10017  Williams    George         NaN         NaN
# 11     10018   Farriss      Anne      1005.0  2012-01-17
# 12     10019     Smith    Olette         NaN         NaN
# 13     10020     Smith     James         NaN         NaN

# %% [markdown]
# 7. Merge the two dataframes customer and invoice into dataframe customerInvoice using inner join.

# %%
customerInvoice = pd.merge(customer, invoice, on='CUS_CODE', how='inner')
customerInvoice
# Out:
#    CUS_CODE CUS_LNAME CUS_FNAME  INV_NUMBER    INV_DATE
# 0     10011     Dunne     Leona        1002  2012-01-16
# 1     10011     Dunne     Leona        1004  2012-01-17
# 2     10011     Dunne     Leona        1008  2012-01-17
# 3     10012     Smith     Kathy        1003  2012-01-16
# 4     10014   Orlando     Myron        1001  2012-01-16
# 5     10014   Orlando     Myron        1006  2012-01-17
# 6     10015   O'Brian       Amy        1007  2012-01-17
# 7     10018   Farriss      Anne        1005  2012-01-17

# %% [markdown]
# 8. Write customerInvoice data to a customerInvoice.csv file.

# %%
customerInvoice.to_csv('customerInvoice.csv')

# %% [markdown]
# 9.Load the three datasets from https://github.com/jakevdp/data-USstates/ into dataframes called population, area and abbreviation

# %%
population = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv')
area = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv')
abbreviation = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv')

# %% [markdown]
# 10.Print the three dataframes you have created in last step one by one

# %%
population.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
area.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbreviation.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %% [markdown]
# 11.Do a many-to-one merge to give us the full state name along with the population.Pick the columns you will use for merging

# %%
abbreviation_population = pd.merge(abbreviation, population, left_on='abbreviation', right_on='state/region')
abbreviation_population.head()
# Out:
#      state abbreviation state/region     ages  year  population
# 0  Alabama           AL           AL  under18  2012   1117489.0
# 1  Alabama           AL           AL    total  2012   4817528.0
# 2  Alabama           AL           AL  under18  2010   1130966.0
# 3  Alabama           AL           AL    total  2010   4785570.0
# 4  Alabama           AL           AL  under18  2011   1125763.0

# %% [markdown]
# 12.Your output from the last commans is only displaying data for Alabama state, kindly fix your code to display information for all the states.

# %%
abbreviation_population
# Out:
#         state abbreviation state/region     ages  year  population
# 0     Alabama           AL           AL  under18  2012   1117489.0
# 1     Alabama           AL           AL    total  2012   4817528.0
# 2     Alabama           AL           AL  under18  2010   1130966.0
# 3     Alabama           AL           AL    total  2010   4785570.0
# 4     Alabama           AL           AL  under18  2011   1125763.0
# ...       ...          ...          ...      ...   ...         ...
# 2443  Wyoming           WY           WY  under18  1993    137458.0
# 2444  Wyoming           WY           WY    total  1991    459260.0
# 2445  Wyoming           WY           WY  under18  1991    136720.0
# 2446  Wyoming           WY           WY  under18  1990    136078.0
# 2447  Wyoming           WY           WY    total  1990    453690.0
#
# [2448 rows x 6 columns]

# %% [markdown]
# 13. Is Puerto Rico included in your result set? If not, fix your code to add it as a new state

# %%
abbreviation_population['state/region'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MT', 'NE',
#        'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'MD',
#        'MA', 'MI', 'MN', 'MS', 'MO', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %% [markdown]
# So we don't have Puerto Rico here. It looks like from the output of the entire dataframe, that we actually have Nan values in our dataset for the state and Abbreviation columns. Let's assume those all belong to Puerto Rico. We shall convert those columns to Puerto Rico.

# %%
abbreviation_population['state'] = abbreviation_population['state'].fillna('Puerto Rico')
abbreviation_population['abbreviation'] = abbreviation_population['abbreviation'].fillna('PR')
abbreviation_population
# Out:
#             state abbreviation state/region     ages  year   population
# 0         Alabama           AL           AL  under18  2012    1117489.0
# 1         Alabama           AL           AL    total  2012    4817528.0
# 2         Alabama           AL           AL  under18  2010    1130966.0
# 3         Alabama           AL           AL    total  2010    4785570.0
# 4         Alabama           AL           AL  under18  2011    1125763.0
# ...           ...          ...          ...      ...   ...          ...
# 2539  Puerto Rico           PR          USA    total  2010  309326295.0
# 2540  Puerto Rico           PR          USA  under18  2011   73902222.0
# 2541  Puerto Rico           PR          USA    total  2011  311582564.0
# 2542  Puerto Rico           PR          USA  under18  2012   73708179.0
# 2543  Puerto Rico           PR          USA    total  2012  313873685.0
#
# [2544 rows x 6 columns]

# %% [markdown]
# 14. Now merge the result set with area so we can see the following information as one:
# state/region 	ages 	year 	population 	state 	area (sq. mi)

# %%
result_df = pd.merge(abbreviation_population, area, left_on='state', right_on='state')
result_df
# Out:
#         state abbreviation state/region     ages  year  population  \
# 0     Alabama           AL           AL  under18  2012   1117489.0
# 1     Alabama           AL           AL    total  2012   4817528.0
# 2     Alabama           AL           AL  under18  2010   1130966.0
# 3     Alabama           AL           AL    total  2010   4785570.0
# 4     Alabama           AL           AL  under18  2011   1125763.0
# ...       ...          ...          ...      ...   ...         ...
# 2443  Wyoming           WY           WY  under18  1993    137458.0
# 2444  Wyoming           WY           WY    total  1991    459260.0
# 2445  Wyoming           WY           WY  under18  1991    136720.0
# 2446  Wyoming           WY           WY  under18  1990    136078.0
# 2447  Wyoming           WY           WY    total  1990    453690.0
#
#       area (sq. mi)
# 0             52423
# 1             52423
# 2             52423
# 3             52423
# 4             52423
# ...             ...
# 2443          97818
# 2444          97818
# 2445          97818
# 2446          97818
# 2447          97818
#
# [2448 rows x 7 columns]

# %% [markdown]
# 15. Load titanic.csv file into dataframe named titanic, print the data

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 16. Pivot the dataframe to hold information in the following format:
# class 	                                  First 	Second  	  Third
# sex
# female  	                              0.968085  	0.921053 	0.500000
# male 	                                  0.368852  	0.157407 	0.135447

# %%
# assuming that we wanted the average values of the survived column for each gender + class:
pivot_1 = titanic.pivot_table(index='sex', columns='class', values='survived', aggfunc='mean')
pivot_1
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
17. Pivot the table further to hold information in the following format:
     	    class 	First 	Second 	Third
sex 	age
female 	(0, 18] 	0.909091 	1.000000 	0.511628
(18, 80] 	0.972973 	0.900000 	0.423729
male 	(0, 18] 	0.800000 	0.600000 	0.215686
(18, 80] 	0.375000 	0.071429 	0.133663

# %%
# notice that the age, which is normally a number, is now a grouping (0-18, 18-80). We need to adjust our age column first, before we do another pivot
titanic['age'] = pd.cut(titanic['age'], [0, 18, 80])
titanic.head()
# Out:
#    survived  pclass     sex       age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  (18, 80]      1      0   7.2500        S  Third
# 1         1       1  female  (18, 80]      1      0  71.2833        C  First
# 2         1       3  female  (18, 80]      0      0   7.9250        S  Third
# 3         1       1  female  (18, 80]      1      0  53.1000        S  First
# 4         0       3    male  (18, 80]      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# assuming again, we want the average values of the survived column:
pivot_2 = titanic.pivot_table(index=['sex', 'age'], columns='class', values='survived', aggfunc='mean')
pivot_2
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
18.Pivot the table further to hold information in the following format:
fare 	survived
class 	First 	Second 	Third 	First 	Second 	Third
sex
female 	106.125798 	21.970121 	16.118810 	91.0 	70.0 	72.0
male 	67.226127 	19.741782 	12.661633 	45.0 	17.0 	47.0

# %%
pivot_3 = titanic.pivot_table(index='sex', columns='class', values=['fare', 'survived'], aggfunc={'fare': 'mean', 'survived': 'sum'})
pivot_3
# Out:
#               fare                        survived
# class        First     Second      Third     First    Second     Third
# sex
# female  106.125798  21.970121  16.118810  0.968085  0.921053  0.500000
# male     67.226127  19.741782  12.661633  0.368852  0.157407  0.135447

# %% [markdown]
# For the rest of the lab, you need to have access to mySQL server, run the given script to create tables and do the rest of the lab after that.
#
#
# - You can create your own, and copy and paste the SQL script from the assignment, into the phpMyAdmin tool.
# - It will create the tables for you, and you can use your own database to answer the questions.
# - It is also totally acceptable if you just use my database instead. The credentials are:
#
#   - host="sql5.freemysqlhosting.net",
#   - user="sql5731151",
#   - password="qe2tuyaYtZ",
#   - database="sql5731151"

# %% [markdown]
# 19. Write the command to establish a connection to the database, write the necessary imports as well.

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0

# %%
import pandas as pd
import mysql.connector

# Replace with your actual database credentials
mydb = mysql.connector.connect(
  host="sql5.freemysqlhosting.net",
  user="sql5757575",
  password="gCTYvUT6AN",
  database="sql5757575"
)

# Create a cursor object
mycursor = mydb.cursor()

# %% [markdown]
# 20.Write a query to retrieve data from the table called "countries"

# %%
sql_query = "SELECT * FROM countries"

# Read data into a pandas DataFrame
df = pd.read_sql(sql_query, mydb)
df.head()
# Out:
# <ipython-input-4-233e1f8003b7>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query, mydb)
#   country_id country_name  region_id
# 0         AR    Argentina          2
# 1         AU    Australia          3
# 2         BE      Belgium          1
# 3         BR       Brazil          2
# 4         CA       Canada          2

# %% [markdown]
# 21.Write a query to report the street address and city of all locations that their city name starts with ‘M’.
# Provide the alias “Street Address” for the street address column.

# %%
query_21 = '''
SELECT street_address AS 'Street Address', city
FROM locations
WHERE city LIKE 'M%'
'''
df_21 = df = pd.read_sql(query_21, mydb)
df_21.head()
# Out:
# <ipython-input-5-3a1bfac1df65>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_21 = df = pd.read_sql(query_21, mydb)
#           Street Address         city
# 0  Mariano Escobedo 9991  Mexico City
# 1  Schwanthalerstr. 7031       Munich

# %% [markdown]
# 22.Write a query to count the total number of employees working in each department.

# %%
query_22 = '''
SELECT department_id, COUNT(*) AS employee_count
FROM employees
GROUP BY department_id
'''
df_22 = pd.read_sql(query_22, mydb)
df_22.head()
# Out:
# <ipython-input-6-a4b013a08843>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_22 = pd.read_sql(query_22, mydb)
#    department_id  employee_count
# 0            NaN               1
# 1           10.0               1
# 2           20.0               2
# 3           50.0               5
# 4           60.0               3

# %% [markdown]
# 23. Write a query to print the name of employee along with the complete address of their department.

# %%
query_23 = '''
SELECT e.first_name, e.last_name, l.street_address, l.city, l.state_province, l.country_id
FROM employees e
JOIN departments d ON e.department_id = d.department_id
JOIN locations l ON d.location_id = l.location_id
'''
df_23 = pd.read_sql(query_23, mydb)
df_23.head()
# Out:
# <ipython-input-7-390815a9eeb1>:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_23 = pd.read_sql(query_23, mydb)
#   first_name last_name       street_address                 city  \
# 0  Alexander    Hunold  2014 Jabberwocky Rd            Southlake
# 1      Bruce     Ernst  2014 Jabberwocky Rd            Southlake
# 2      Diana   Lorentz  2014 Jabberwocky Rd            Southlake
# 3      Kevin   Mourgos  2011 Interiors Blvd  South San Francisco
# 4     Trenna      Rajs  2011 Interiors Blvd  South San Francisco
#
#   state_province country_id
# 0          Texas         US
# 1          Texas         US
# 2          Texas         US
# 3     California         US
# 4     California         US

# %% [markdown]
# 24.Close the connection

# %%
mydb.close()
