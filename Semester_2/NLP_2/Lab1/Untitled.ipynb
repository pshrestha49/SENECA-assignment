# %%
# !pip install pandas
# Out:
# ...
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.3/11.3 MB 8.3 MB/s eta 0:00:02
#      ---                                      1.1/11.3 MB 14.3 MB/s eta 0:00:01
#      --------                                 2.3/11.3 MB 18.2 MB/s eta 0:00:01
#      ------------                             3.5/11.3 MB 20.1 MB/s eta 0:00:01
#      -----------------                        4.9/11.3 MB 22.4 MB/s eta 0:00:01
#      ----------------------                   6.5/11.3 MB 24.4 MB/s eta 0:00:01
#      ----------------------------             8.0/11.3 MB 25.7 MB/s eta 0:00:01
#      ---------------------------------        9.6/11.3 MB 26.6 MB/s eta 0:00:01
#      -------------------------------------   10.8/11.3 MB 29.7 MB/s eta 0:00:01
#      --------------------------------------  11.3/11.3 MB 28.5 MB/s eta 0:00:01
#      --------------------------------------  11.3/11.3 MB 28.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
